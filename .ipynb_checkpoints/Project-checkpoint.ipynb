# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pd.read_csv(r""C:\Users\LENOVO\Downloads\Book1 (1).csv)

# %%
df.head()
# Out:
#    PH_FLD  EC_FLD    DO       Temp     TDS     SS        CO3         HCO3  \
# 0    6.66   515.0  4.23  26.200001  7840.0  120.0   0.000000  2257.000000
# 1    6.45   430.0  4.20  30.600000  8339.0  210.0   0.000000   256.200012
# 2    6.49  5120.0  4.20  30.000000  2525.0   65.0  47.639999   665.631958
# 3    7.15   150.0  3.80  27.299999  1980.0  150.0   0.000000  1555.500000
# 4    7.00   252.0  7.50  29.000000   870.0   75.0   0.000000   152.500000
#
#      DO_SAT%        SAR
# 0  52.157188   1.479916
# 1  55.619854  17.347925
# 2  55.562901  50.183250
# 3  47.716095   2.825108
# 4  97.516579   3.369744

# %%
df.columns
# Out:
# Index(['PH_FLD', 'EC_FLD', 'DO', 'Temp', 'TDS', 'SS', 'CO3', 'HCO3', 'DO_SAT%',
#        'SAR'],
#       dtype='object')

# %%
df.tail()
# Out:
#      PH_FLD   EC_FLD   DO  Temp     TDS  SS   CO3   HCO3   DO_SAT%        SAR
# 186    6.00    900.0  NaN  20.0  8450.0 NaN   6.0   34.0       NaN  34.242893
# 187    5.85  18650.0  5.6  33.5   650.0 NaN   6.0   46.0  78.02594   3.302766
# 188    5.80    900.0  NaN  30.0  3965.0 NaN   9.0   73.0       NaN  20.605415
# 189    5.20  15000.0  NaN  27.0  3523.0 NaN  18.0  124.0       NaN  15.132142
# 190    5.10  11000.0  NaN  20.0  2964.0 NaN   3.0  238.0       NaN  13.469092

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   PH_FLD   184 non-null    float64
#  1   EC_FLD   184 non-null    float64
#  2   DO       70 non-null     float64
#  3   Temp     189 non-null    float64
#  4   TDS      182 non-null    float64
#  5   SS       45 non-null     float64
#  6   CO3      163 non-null    float64
#  7   HCO3     163 non-null    float64
#  8   DO_SAT%  70 non-null     float64
#  9   SAR      163 non-null    float64
# dtypes: float64(10)
# memory usage: 15.0 KB

# %%
df.shape
# Out:
# (191, 10)

# %%
df.describe()
# Out:
#            PH_FLD        EC_FLD         DO        Temp           TDS  \
# count  184.000000    184.000000  70.000000  189.000000    182.000000
# mean     5.772283   7876.577174   5.574286   28.104233   5268.892034
# std      1.078352   8027.836819   4.259334    3.008018   4740.961173
# min      2.580000      7.000000   0.000000   20.000000     75.000000
# 25%      5.100000    900.000000   2.912500   26.500000   1502.250000
# 50%      5.500000   4650.000000   4.900000   28.000000   5073.500000
# 75%      6.512500  13782.500000   7.000000   30.000000   7502.625000
# max      8.300000  35000.000000  27.500000   35.500000  35685.000000
#
#                 SS         CO3         HCO3     DO_SAT%         SAR
# count    45.000000  163.000000   163.000000   70.000000  163.000000
# mean    196.466667    9.197913   350.631920   71.124291   20.020803
# std     340.269920   21.513015   576.573833   53.873005   31.531534
# min      10.000000    0.000000     6.000000    0.000000    0.041801
# ...

# %%
df.isnull().sum()
# Out:
# PH_FLD       7
# EC_FLD       7
# DO         121
# Temp         2
# TDS          9
# SS         146
# CO3         28
# HCO3        28
# DO_SAT%    121
# SAR         28
# dtype: int64

# %%
data1= df.fillna(value=df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# PH_FLD     0
# EC_FLD     0
# DO         0
# Temp       0
# TDS        0
# SS         0
# CO3        0
# HCO3       0
# DO_SAT%    0
# SAR        0
# dtype: int64

# %%
df
# Out:
#      PH_FLD   EC_FLD        DO       Temp     TDS          SS        CO3  \
# 0      6.66    515.0  4.230000  26.200001  7840.0  120.000000   0.000000
# 1      6.45    430.0  4.200000  30.600000  8339.0  210.000000   0.000000
# 2      6.49   5120.0  4.200000  30.000000  2525.0   65.000000  47.639999
# 3      7.15    150.0  3.800000  27.299999  1980.0  150.000000   0.000000
# 4      7.00    252.0  7.500000  29.000000   870.0   75.000000   0.000000
# ..      ...      ...       ...        ...     ...         ...        ...
# 186    6.00    900.0  5.574286  20.000000  8450.0  196.466667   6.000000
# 187    5.85  18650.0  5.600000  33.500000   650.0  196.466667   6.000000
# 188    5.80    900.0  5.574286  30.000000  3965.0  196.466667   9.000000
# 189    5.20  15000.0  5.574286  27.000000  3523.0  196.466667  18.000000
# 190    5.10  11000.0  5.574286  20.000000  2964.0  196.466667   3.000000
#
#             HCO3    DO_SAT%        SAR
# 0    2257.000000  52.157188   1.479916
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
corr = df.corr()
f, ax = plt.subplots(figsize=(15, 10))
fig_corr = sns.heatmap(corr, annot=True)
plt.title("Correlation")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler1 = scaler.fit_transform(df.values.reshape(-1, 1))
scaler2 = scaler.transform(df.values.reshape(-1, 1))
